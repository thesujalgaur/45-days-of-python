# %%
#seaborn is a library for making stastical 
#graphics in python . It is built on the top of
#matplotlib and is heavily inspired by R's ggplot2.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 

# Load the built-in 'tips' dataset
tips = sns.load_dataset("tips")

# Create a bar plot of average tip amount by day
sns.barplot(x="day", y="tip", data=tips, palette="viridis")

# Add title and labels
plt.title("Average Tip by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Average Tip")

# Show the plot
plt.show()
# Out:
# /var/folders/x6/3z1b_1m13nn8gl_5jykvtxy40000gn/T/ipykernel_8957/24923037.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="tip", data=tips, palette="viridis")

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#sns.lineplot(df["total_bill"])
#sns.scatterplot(df["total_bill"])
sns.scatterplot(x="total_bill",y="tip",data=df)
plt.title("scatterplot")
plt.show()

# %%
sns.histplot(df["total_bill"],color="blue",edgecolor="pink")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x="tip",y="total_bill",data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
##sns -- 1 categorical -- catploy
#2 numerical -- scatter plot , line plot --> relational -- relplot 
sns.relplot(x="total_bill",y="tip",data=df,kind="scatter",hue="smoker",
            style="size",col="day")  # for column use row="day"

# %%
#catplot
sns.catplot(x="day",y="total_bill",data=df,kind="swarm") #swarm reduces overlapping

# %%
#countplot
sns.countplot(x="day",data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.barplot(x="total_bill",y="tip",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pointplot(x="day",y="total_bill",data=df,hue="sex") #used for comapring #used for mean of the data
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#box plot teels the spread of data in form of boxxx
sns.boxplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(df) # pairplot create chart between  all numerical feature

# %%
sns.histplot(df["tip"],kde=True) #depict density plot in histplot
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.boxplot(df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
##outliers handle 
q1=df["total_bill"].quantile(0.25)
q3=df["total_bill"].quantile(0.75)
iqr=q3-q1 
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr
print(lower_limit,upper_limit)
df[df["total_bill"]>upper_limit]
df=df[(df["total_bill"]>lower_limit) & (df["total_bill"]<upper_limit)]
sns.boxplot(df["total_bill"])
# Out:
# -2.8224999999999945 40.29749999999999
# <Axes: ylabel='total_bill'>
